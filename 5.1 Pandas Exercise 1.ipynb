# %%
# %matplotlib inline
import pandas as pd

# %%
titles = pd.read_csv('Desktop/Springboard/data/titles.csv')
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
cast = pd.read_csv('Desktop/Springboard/data/cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
# How many movies are listed in the titles dataframe?
len(titles)
# Out:
# 230621

# %%
# What are the earliest two films listed in the titles dataframe?
titles.sort_values('year').head(2)
# Out:
#                      title  year
# 176477          Miss Jerry  1894
# 213694  The Startled Lover  1898

# %%
# How many movies have the title "Hamlet"?
len(titles[titles.title == 'Hamlet'])
# Out:
# 18

# %%
(titles['title'] == 'Hamlet').value_counts()
# Out:
# False    230603
# True         18
# Name: title, dtype: int64

# %%
# How many movies are titled "North by Northwest"?
(titles['title'] == 'North by Northwest').value_counts()
# Out:
# False    230620
# True          1
# Name: title, dtype: int64

# %%
# When was the first movie titled "Hamlet" made?
(titles['title'] == 'Hamlet').sort_values('year')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-3e34b669a3ce> in <module>
#       1 # When was the first movie titled "Hamlet" made?
# ----> 2 (titles['title'] == 'Hamlet').sort_values('year')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    3135         inplace = validate_bool_kwarg(inplace, "inplace")
#    3136         # Validate the axis parameter
# -> 3137         self._get_axis_number(axis)
#    3138
#    3139         # GH 5856/5853
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     409             except KeyError:
#     410                 pass
# --> 411         raise ValueError("No axis named {0} for object type {1}".format(axis, cls))
#     412
#     413     @classmethod
#
# ...

# %%
# When was the first movie titled "Hamlet" made?
titles[titles.title == 'Hamlet'].sort_values('year')
# Out:
#          title  year
# 46365   Hamlet  1910
# 208366  Hamlet  1911
# 165217  Hamlet  1913
# 97869   Hamlet  1921
# 5969    Hamlet  1948
# 127468  Hamlet  1954
# 181662  Hamlet  1964
# 121837  Hamlet  1969
# 219855  Hamlet  1973
# 91506   Hamlet  1976
# 93696   Hamlet  1987
# 45010   Hamlet  1990
# 199837  Hamlet  1996
# 93894   Hamlet  2000
# 174816  Hamlet  2009
# 102208  Hamlet  2011
# 221923  Hamlet  2014
# 167748  Hamlet  2015

# %%
# List all of the "Treasure Island" movies from earliest to most recent.
titles[titles.title == 'Treasure Island'].sort_values('year')
# Out:
#                   title  year
# 204540  Treasure Island  1918
# 50896   Treasure Island  1920
# 189691  Treasure Island  1934
# 96259   Treasure Island  1950
# 59186   Treasure Island  1972
# 110576  Treasure Island  1973
# 203909  Treasure Island  1985
# 178072  Treasure Island  1999

# %%
# How many movies were made in the year 1950?
(titles['year'] == 1950).value_counts()
# Out:
# False    229528
# True       1093
# Name: year, dtype: int64

# %%
len(titles[titles.year == 1950])
# Out:
# 1093

# %%
# How many movies were made in the year 1960?
(titles['year'] == 1960).value_counts()
# Out:
# False    229125
# True       1496
# Name: year, dtype: int64

# %%
# How many movies were made from 1950 through 1959?
((titles['year'] >= 1950) & (titles['year'] <= 1959)).value_counts()
# Out:
# False    217965
# True      12656
# Name: year, dtype: int64

# %%
# In what years has a movie titled "Batman" been released?
titles[titles.title == 'Batman'].sort_values('year')
# Out:
#         title  year
# 74047  Batman  1943
# 55577  Batman  1989

# %%
# How many roles were there in the movie "Inception"?
(cast['title'] == 'Inception').value_counts()
# Out:
# False    3611135
# True          77
# Name: title, dtype: int64

# %%
len(cast[cast.title == 'Inception'])
# Out:
# 77

# %%
cast[cast.title == 'Inception']
# Out:
#              title  year                  name     type  \
# 94333    Inception  2010  Michael (III) August    actor
# 143138   Inception  2010          Peter Basham    actor
# 176819   Inception  2010          Tom Berenger    actor
# 190249   Inception  2010              Ken Bhan    actor
# 250191   Inception  2010        Virgile Bramly    actor
# ...            ...   ...                   ...      ...
# 3238950  Inception  2010            Ellen Page  actress
# 3292669  Inception  2010        Nicole Pulliam  actress
# 3319073  Inception  2010    Lisa (II) Reynolds  actress
# 3325768  Inception  2010         Talulah Riley  actress
# 3560127  Inception  2010        Shannon Welles  actress
#
#                      character     n
# 94333            LAX Passenger   NaN
# 143138   Fischer's Jet Captain  44.0
# 176819                Browning   8.0
# 190249        Mombasan Gambler   NaN
# 250191          Bridge Sub Con  29.0
# ...                        ...   ...
# ...

# %%
# How many roles in the movie "Inception" are NOT ranked by an "n" value? >>> True
cast[cast.title == 'Inception'].n.isnull()
# Out:
# 94333       True
# 143138     False
# 176819     False
# 190249      True
# 250191     False
#            ...
# 3238950    False
# 3292669    False
# 3319073    False
# 3325768    False
# 3560127    False
# Name: n, Length: 77, dtype: bool

# %%
(cast[cast.title == 'Inception'].n.isnull()).value_counts()
# Out:
# False    51
# True     26
# Name: n, dtype: int64

# %%
# But how many roles in the movie "Inception" did receive an "n" value?  >>> True
(cast[cast.title == 'Inception'].n.notnull()).value_counts()
# Out:
# True     51
# False    26
# Name: n, dtype: int64

# %%
# Display the cast of "North by Northwest" in their correct "n"-value order, 
# ignoring roles that did not earn a numeric "n" value.

c = cast
c = c[c.title == 'North by Northwest']
c = c[c.n.notnull()]
c = c.sort_values('n')
c
# Out:
#                       title  year                  name     type  \
# 840374   North by Northwest  1959            Cary Grant    actor
# 3361396  North by Northwest  1959       Eva Marie Saint  actress
# 1404704  North by Northwest  1959           James Mason    actor
# 3024085  North by Northwest  1959   Jessie Royce Landis  actress
# 343701   North by Northwest  1959        Leo G. Carroll    actor
# 2923056  North by Northwest  1959  Josephine Hutchinson  actress
# 1634552  North by Northwest  1959           Philip Ober    actor
# 1229083  North by Northwest  1959         Martin Landau    actor
# 2357939  North by Northwest  1959         Adam Williams    actor
# 1746383  North by Northwest  1959          Edward Platt    actor
# 642085   North by Northwest  1959     Robert Ellenstein    actor
# 2212083  North by Northwest  1959          Les Tremayne    actor
# 447893   North by Northwest  1959       Philip Coolidge    actor
# ...

# %%
# Display the entire cast, in "n"-order, of the 1972 film "Sleuth".
c = cast
c = c[c.title == 'Sleuth']
c = c[c.year == 1972]
c = c.sort_values('n')
c
# Out:
#           title  year                name     type  \
# 1644328  Sleuth  1972    Laurence Olivier    actor
# 314691   Sleuth  1972       Michael Caine    actor
# 360365   Sleuth  1972      Alec Cawthorne    actor
# 1412647  Sleuth  1972  John (II) Matthews    actor
# 2619278  Sleuth  1972  Eve (III) Channing  actress
# 1396572  Sleuth  1972        Teddy Martin    actor
#
#                           character    n
# 1644328                 Andrew Wyke  1.0
# 314691                  Milo Tindle  2.0
# 360365            Inspector Doppler  3.0
# 1412647  Detective Sergeant Tarrant  4.0
# 2619278             Marguerite Wyke  5.0
# 1396572      Police Constable Higgs  6.0

# %%
# Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".
c = cast
c = c[c.title == 'Sleuth']
c = c[c.year == 2007]
c = c.sort_values('n')
c
# Out:
#           title  year                 name     type          character    n
# 314692   Sleuth  2007        Michael Caine    actor             Andrew  1.0
# 1246855  Sleuth  2007             Jude Law    actor               Milo  2.0
# 1741124  Sleuth  2007        Harold Pinter    actor        Man on T.V.  3.0
# 250297   Sleuth  2007      Kenneth Branagh    actor  Other Man on T.V.  NaN
# 360366   Sleuth  2007  Alec (II) Cawthorne    actor  Inspector Doppler  NaN
# 2619277  Sleuth  2007    Eve (II) Channing  actress    Marguerite Wyke  NaN
# 3223502  Sleuth  2007    Carmel O'Sullivan  actress             Maggie  NaN

# %%
# How many roles were credited in the silent 1921 version of Hamlet?

(cast.title == 'Hamlet') & (cast.year == 1921)
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 3611207    False
# 3611208    False
# 3611209    False
# 3611210    False
# 3611211    False
# Length: 3611212, dtype: bool

# %%
cast[(cast.title == 'Hamlet') & (cast.year == 1921)]
# Out:
#           title  year                    name     type         character    n
# 7438     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 442224   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 535307   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1095274  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2106367  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2289163  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2562876  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 2935728  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3209199  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %%
len(cast[(cast.title == 'Hamlet') & (cast.year == 1921)])
# Out:
# 9

# %%
# How many roles were credited in Branagh’s 1996 Hamlet?
cast[(cast.title == 'Hamlet') & (cast.year == 1996)]
# Out:
#           title  year                    name     type  \
# 1615     Hamlet  1996              Riz Abbasi    actor
# 92106    Hamlet  1996    Richard Attenborough    actor
# 152349   Hamlet  1996     Simon Russell Beale    actor
# 206181   Hamlet  1996         David (V) Blair    actor
# 211111   Hamlet  1996           Brian Blessed    actor
# 241315   Hamlet  1996      Christopher Bowles    actor
# 250281   Hamlet  1996         Kenneth Branagh    actor
# 262368   Hamlet  1996          Richard Briers    actor
# 283598   Hamlet  1996          Michael Bryant    actor
# 307699   Hamlet  1996            Peter Bygott    actor
# 331657   Hamlet  1996       Kenneth W Caravan    actor
# 482982   Hamlet  1996           Billy Crystal    actor
# 500005   Hamlet  1996           Charles Daish    actor
# 555725   Hamlet  1996        G?rard Depardieu    actor
# 577284   Hamlet  1996          Reece Dinsdale    actor
# 582748   Hamlet  1996                Ken Dodd    actor
# ...

# %%
len(cast[(cast.title == 'Hamlet') & (cast.year == 1996)])
# Out:
# 54

# %%
# How many "Hamlet" roles have been listed in all film credits through history?
cast[cast.character == 'Hamlet']
# Out:
#                                  title  year               name     type  \
# 6003                             Sugar  2008       Hamlet Abreu    actor
# 94018                  Top of the Town  1937        Mischa Auer    actor
# 120093             The Sound of Spying  2014      Jonathan Ball    actor
# 154451                Suivez cet avion  1989  Fran?ois Beaulieu    actor
# 154754          Nous sommes les autres  2017       Marc Beaupr?    actor
# ...                                ...   ...                ...      ...
# 2517189                       Hamlet_X  2003       Meret Becker  actress
# 2622924  Bill Shakespeare in Hollywood  2011    Rafika Chawishe  actress
# 2825750    Intikam Melegi/Kadin Hamlet  1976        Fatma Girik  actress
# 3209199                         Hamlet  1921       Asta Nielsen  actress
# 3256505                         Hamlet  2015       Maxine Peake  actress
#
#         character     n
# 6003       Hamlet  58.0
# 94018      Hamlet   6.0
# ...

# %%
len(cast[cast.character == 'Hamlet'])
# Out:
# 91

# %%
# How many people have played an "Ophelia"?
len(cast[cast.character == 'Ophelia'])   ### Wrong Answer
# Out:
# 111

# %%
len(cast[cast.character == "Ophelia"].name.unique())   ### Correct Answer
# Out:
# 109

# %%
# How many people have played a role called "The Dude"?
len(cast[cast.character == "The Dude"].name.unique())  ### Correct
# Out:
# 18

# %%
len(cast[cast.character == "The Dude"]) ### Wrong
# Out:
# 18

# %%
# How many people have played a role called "The Stranger"?
len(cast[cast.character == "The Stranger"].name.unique())   ### Correct
# Out:
# 197

# %%
len(cast[cast.character == "The Stranger"])   ### Wrong
# Out:
# 208

# %%
# How many roles has Sidney Poitier played throughout his career?
len(cast[cast.name == "Sidney Poitier"])
# Out:
# 43

# %%
# How many roles has Judi Dench played?
len(cast[cast.name == "Judi Dench"])
# Out:
# 55

# %%
# List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.
cast[(cast.name == 'Cary Grant') & (cast.n == 2) & (cast.year // 10 == 194)].sort_values('year')
# Out:
#                    title  year        name   type    character    n
# 840371  My Favorite Wife  1940  Cary Grant  actor         Nick  2.0
# 840381    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %%
# List the leading roles that Cary Grant played in the 1940s in order by year.
cast[(cast.name == 'Cary Grant') & (cast.n == 1) & (cast.year // 10 == 194)].sort_values('year')
# Out:
#                                        title  year        name   type  \
# 840397               The Howards of Virginia  1940  Cary Grant  actor
# 840353                       His Girl Friday  1940  Cary Grant  actor
# 840399                The Philadelphia Story  1940  Cary Grant  actor
# 840386                             Suspicion  1941  Cary Grant  actor
# 840401                  The Talk of the Town  1942  Cary Grant  actor
# 840377                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 840344                     Destination Tokyo  1943  Cary Grant  actor
# 840369                             Mr. Lucky  1943  Cary Grant  actor
# 840370                             Mr. Lucky  1943  Cary Grant  actor
# 840378                      Once Upon a Time  1944  Cary Grant  actor
# 840336                  Arsenic and Old Lace  1944  Cary Grant  actor
# 840373             None But the Lonely Heart  1944  Cary Grant  actor
# ...

# %%
# How many roles were available for actors in the 1950s?
len(cast[(cast.type == 'actor') & (cast.year // 10 == 195)])
# Out:
# 154727

# %%
# How many leading roles (n=1) were available from the beginning of film history through 1980?
len(cast[(cast.year <= 1980) & (cast.n == 1)])
# Out:
# 63924

# %%
# How many non-leading roles were available through from the beginning of film history through 1980?
len(cast[(cast.year <= 1980) & (cast.n != 1)])
# Out:
# 1094780

# %%
# How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?
len(cast[(cast.year <= 1980) & (cast.n.isnull())])
# Out:
# 438086
